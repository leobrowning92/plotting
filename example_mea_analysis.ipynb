# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mea_analysis as mea

# %%
# use your data here
filepath = "exampledata/MEA001_postS_5V_SMU.tdms"

smudf, vdf = mea.open_data(filepath)

# %%
mea.plot_signal(vdf,smudf,show=True)

# %%
dg, iei =mea.analyze_events(smudf,gthresh=0.01)

# %%
fig, ax = plt.subplots(nrows=1,figsize=(15,5))
ax.eventplot(dg[:,1],linewidth=1,color='k')
ax2=ax.twinx()
ax2.plot(smudf.trel,smudf.conductance,'r')

# %%
resd=vdf.iloc[:,3:-1].values[43400:43600]
mea.plot_principal_components(resd, displaynan = [], show = True, ends = True)
# Out:
# (<Figure size 453.6x453.6 with 6 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4277843828>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f4277801ac8>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7f427781d080>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f42777b45f8>]],
#        dtype=object))
